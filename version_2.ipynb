# %% [markdown]
# # Agricultural Pest Detection — DLP Week 10
#
# **Goal**: Detect and classify 23 agricultural pest species → maximize mAP@IoU=0.5
# **Model**: YOLOv8x (pretrained COCO → fine-tuned on pest data)
# **Dataset**: 12,701 training images · 2,580 test images · 800×600 px · 102,472 annotations

# %% [markdown]
# ## 0. Install & Imports

# %%
# !pip install ultralytics -q

# %%
import os
import shutil
import random
import warnings
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')   # render to file only — prevents large inline PNG output
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from pathlib import Path
from PIL import Image
from collections import Counter
import yaml
import torch
from tqdm.auto import tqdm

warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 72
plt.rcParams['figure.figsize'] = (12, 4)

PLOT_DIR = Path('/kaggle/working/plots')
PLOT_DIR.mkdir(exist_ok=True)

print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU     : {torch.cuda.get_device_name(0)}")
    print(f"VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %% [markdown]
# ## 1. Configuration

# %%
KAGGLE_INPUT = Path('/kaggle/input')
WORK_DIR     = Path('/kaggle/working')

# Search recursively for the folder containing train.csv
BASE_DIR = None
for p in sorted(KAGGLE_INPUT.rglob('train.csv')):
    BASE_DIR = p.parent
    break

if BASE_DIR is None:
    raise FileNotFoundError(
        f"train.csv not found anywhere under {KAGGLE_INPUT}.\n"
        f"Contents: {list(KAGGLE_INPUT.rglob('*'))[:30]}"
    )

print(f"Dataset root : {BASE_DIR}")

TRAIN_CSV  = BASE_DIR / 'train.csv'
SAMPLE_SUB = BASE_DIR / 'sample_submission.csv'
TEST_DIR   = BASE_DIR / 'test'

_train_subdir = BASE_DIR / 'train'
TRAIN_IMG_DIR = _train_subdir if _train_subdir.is_dir() else BASE_DIR
print(f"Train images : {TRAIN_IMG_DIR}")
print(f"Test  images : {TEST_DIR}")

DATASET_DIR = WORK_DIR / 'dataset'

# ── Model & Training ──────────────────────────────────────────────────────────
# yolov8m @ 640px, batch=16 → ~3.5 GPU hours for 40 epochs
# Leaves 26+ hrs of weekly budget for a second run after reviewing leaderboard score
MODEL_NAME = 'yolov8m.pt'
IMG_SIZE   = 640
EPOCHS     = 40
BATCH_SIZE = 16
VAL_SPLIT  = 0.1
SEED       = 42

# ── Inference ─────────────────────────────────────────────────────────────────
CONF_THRESH = 0.25
NMS_IOU     = 0.5
INFER_BATCH = 32   # larger batch is fine at inference time

# ── Reproducibility ───────────────────────────────────────────────────────────
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

assert TRAIN_CSV.exists(),     f"train.csv not found at {TRAIN_CSV}"
assert TEST_DIR.exists(),      f"test/ folder not found at {TEST_DIR}"
assert SAMPLE_SUB.exists(),    f"sample_submission.csv not found at {SAMPLE_SUB}"
assert TRAIN_IMG_DIR.exists(), f"Training images folder not found at {TRAIN_IMG_DIR}"
print("All paths validated.")
# Out:
# Dataset root : /kaggle/input/competitions/object-detetction-week-10-dlp
# Train images : /kaggle/input/competitions/object-detetction-week-10-dlp/train
# Test  images : /kaggle/input/competitions/object-detetction-week-10-dlp/test
# All paths validated.

# %% [markdown]
# ## 2. Exploratory Data Analysis
#
# Understanding the data **before** training lets us make informed hyperparameter decisions rather than guessing.

# %%
df = pd.read_csv(TRAIN_CSV)

# Derived columns
df['bbox_w']      = df['x_max'] - df['x_min']
df['bbox_h']      = df['y_max'] - df['y_min']
df['bbox_area']   = df['bbox_w'] * df['bbox_h']
df['rel_w']       = df['bbox_w'] / df['width']   # fraction of image width
df['rel_h']       = df['bbox_h'] / df['height']
df['aspect_ratio']= df['bbox_w'] / df['bbox_h']

print("=" * 55)
print(f"  Total annotations : {len(df):,}")
print(f"  Training images   : {df['image_id'].nunique():,}")
print(f"  Test images       : {len(list(TEST_DIR.glob('*.jpg'))):,}")
print(f"  Number of classes : {df['class_name'].nunique()}")
print(f"  Image resolution  : {df['width'].iloc[0]}×{df['height'].iloc[0]}")
print("=" * 55)
print()
print("Missing values:")
print(df.isnull().sum())
# Out:
# =======================================================
#   Total annotations : 102,472
#   Training images   : 12,701
#   Test images       : 7,600
#   Number of classes : 23
#   Image resolution  : 800×600
# =======================================================
#
# Missing values:
# image_id        0
# class_name      0
# x_min           0
# y_min           0
# x_max           0
# y_max           0
# width           0
# height          0
# bbox_w          0
# bbox_h          0
# bbox_area       0
# rel_w           0
# rel_h           0
# aspect_ratio    0
# dtype: int64

# %% [markdown]
# ### 2.1 Class Distribution
# **Finding**: Extreme imbalance — RiceWaterWeevil (29,735) vs WhiteMarginedMoth (54), a 550× ratio.

# %%
class_counts = df['class_name'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

colors = plt.cm.RdYlGn(np.linspace(0.2, 0.85, len(class_counts)))[::-1]
axes[0].barh(class_counts.index[::-1], class_counts.values[::-1], color=colors)
axes[0].set_xlabel('Number of Annotations')
axes[0].set_title('Class Distribution (annotation count)')
for i, (v, name) in enumerate(zip(class_counts.values[::-1], class_counts.index[::-1])):
    axes[0].text(v + 100, i, str(v), va='center', fontsize=8)

axes[1].barh(class_counts.index[::-1], class_counts.values[::-1], color=colors)
axes[1].set_xscale('log')
axes[1].set_xlabel('Number of Annotations (log scale)')
axes[1].set_title('Class Distribution (log scale)')

plt.tight_layout()
plt.savefig(PLOT_DIR / 'class_distribution.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/class_distribution.png")

print(f"\nImbalance ratio (max/min): {class_counts.max() / class_counts.min():.0f}×")
print(f"\nClasses with < 500 samples (rare):")
print(class_counts[class_counts < 500])
# Out:
# Saved → /kaggle/working/plots/class_distribution.png
#
# Imbalance ratio (max/min): 551×
#
# Classes with < 500 samples (rare):
# class_name
# YellowCutworm        444
# CornBorer            428
# LargeCutworm         378
# MoleCricket          219
# RiceGallMidge        100
# Wireworm              99
# WhiteMarginedMoth     54
# Name: count, dtype: int64

# %% [markdown]
# ### 2.2 Bounding Box Size Distribution
# **Finding**: Objects are small — mean ~34×34 px on 800×600 images (~4% of image width). This drives using `imgsz=800` instead of 640.

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

axes[0, 0].hist(df['bbox_w'], bins=60, color='steelblue', edgecolor='white')
axes[0, 0].axvline(df['bbox_w'].median(), color='red', linestyle='--', label=f"Median={df['bbox_w'].median():.0f}px")
axes[0, 0].set_title('BBox Width (px)'); axes[0, 0].set_xlabel('Width (px)'); axes[0, 0].legend()

axes[0, 1].hist(df['bbox_h'], bins=60, color='darkorange', edgecolor='white')
axes[0, 1].axvline(df['bbox_h'].median(), color='red', linestyle='--', label=f"Median={df['bbox_h'].median():.0f}px")
axes[0, 1].set_title('BBox Height (px)'); axes[0, 1].set_xlabel('Height (px)'); axes[0, 1].legend()

axes[0, 2].hist(df['rel_w'] * 100, bins=60, color='seagreen', edgecolor='white')
axes[0, 2].axvline(df['rel_w'].median() * 100, color='red', linestyle='--',
                   label=f"Median={df['rel_w'].median()*100:.1f}%")
axes[0, 2].set_title('Relative BBox Width (%)'); axes[0, 2].set_xlabel('Width (%)'); axes[0, 2].legend()

axes[1, 0].hist(df['bbox_area'], bins=80, color='purple', edgecolor='white')
axes[1, 0].axvline(df['bbox_area'].median(), color='red', linestyle='--',
                   label=f"Median={df['bbox_area'].median():.0f}px²")
axes[1, 0].set_title('BBox Area (px²)'); axes[1, 0].set_xlabel('Area (px²)'); axes[1, 0].legend()

axes[1, 1].hist(df['aspect_ratio'], bins=60, color='crimson', edgecolor='white')
axes[1, 1].axvline(1.0, color='black', linestyle='--', label='Square (1.0)')
axes[1, 1].set_title('Aspect Ratio (W/H)'); axes[1, 1].set_xlabel('Aspect Ratio'); axes[1, 1].legend()

sample = df.sample(min(3000, len(df)), random_state=42)
axes[1, 2].scatter(sample['bbox_w'], sample['bbox_h'], alpha=0.3, s=5, color='navy')
axes[1, 2].plot([0, 160], [0, 160], 'r--', label='Square')
axes[1, 2].set_title('BBox Width vs Height'); axes[1, 2].set_xlabel('Width (px)'); axes[1, 2].set_ylabel('Height (px)'); axes[1, 2].legend()

plt.tight_layout()
plt.savefig(PLOT_DIR / 'bbox_stats.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/bbox_stats.png")
print(df[['bbox_w', 'bbox_h', 'bbox_area', 'rel_w']].describe().round(2))
# Out:
# Saved → /kaggle/working/plots/bbox_stats.png
#           bbox_w     bbox_h  bbox_area      rel_w
# count  102472.00  102472.00  102472.00  102472.00
# mean       34.09      34.25    1282.88       0.04
# std        12.99      12.96     957.84       0.02
# min         3.00       3.00      12.00       0.00
# 25%        25.00      25.00     651.00       0.03
# 50%        32.00      32.00    1015.00       0.04
# 75%        41.00      41.00    1656.00       0.05
# max       155.00     115.00    9610.00       0.19

# %% [markdown]
# ### 2.3 Object Size by Class
# **Finding**: Some classes (e.g. Wireworm, GrainSpreaderThrips) have significantly smaller bounding boxes than others.

# %%
class_size = df.groupby('class_name')['bbox_area'].median().sort_values()

plt.figure(figsize=(12, 6))
colors = plt.cm.coolwarm(np.linspace(0.1, 0.9, len(class_size)))
plt.barh(class_size.index, class_size.values, color=colors)
plt.xlabel('Median BBox Area (px²)')
plt.title('Median Object Size per Class')
plt.tight_layout()
plt.savefig(PLOT_DIR / 'class_size.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/class_size.png")
# Out:
# Saved → /kaggle/working/plots/class_size.png

# %% [markdown]
# ### 2.4 Objects Per Image
# **Finding**: Median 3 objects/image, max 202 — high-density images are real. Mosaic augmentation helps with these.

# %%
objs_per_img = df.groupby('image_id').size()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(objs_per_img, bins=50, color='steelblue', edgecolor='white')
axes[0].axvline(objs_per_img.median(), color='red', linestyle='--', label=f'Median={objs_per_img.median():.0f}')
axes[0].axvline(objs_per_img.mean(), color='orange', linestyle='--', label=f'Mean={objs_per_img.mean():.1f}')
axes[0].set_title('Objects Per Image'); axes[0].set_xlabel('# Objects'); axes[0].legend()

bins = [1, 2, 5, 10, 20, 50, 100, 250]
counts = pd.cut(objs_per_img, bins=bins, right=False).value_counts().sort_index()
axes[1].bar(range(len(counts)), counts.values, color='darkorange', edgecolor='white')
axes[1].set_xticks(range(len(counts)))
axes[1].set_xticklabels([str(b) for b in counts.index], rotation=30)
axes[1].set_title('Object Count Distribution (binned)')
axes[1].set_xlabel('# Objects per image'); axes[1].set_ylabel('# Images')

plt.tight_layout()
plt.savefig(PLOT_DIR / 'objs_per_image.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/objs_per_image.png")
print(f"Images with 1 object   : {(objs_per_img == 1).sum():,}")
print(f"Images with >10 objects: {(objs_per_img > 10).sum():,}")
print(f"Images with >50 objects: {(objs_per_img > 50).sum():,}")
# Out:
# Saved → /kaggle/working/plots/objs_per_image.png
# Images with 1 object   : 3,464
# Images with >10 objects: 2,502
# Images with >50 objects: 300

# %% [markdown]
# ### 2.5 Bounding Box Position Heatmap
# **Finding**: Object positions are fairly uniform across the image — no strong spatial bias.

# %%
cx = ((df['x_min'] + df['x_max']) / 2) / df['width']
cy = ((df['y_min'] + df['y_max']) / 2) / df['height']

heatmap, xedges, yedges = np.histogram2d(cx, cy, bins=30)

plt.figure(figsize=(7, 5))
plt.imshow(heatmap.T, origin='lower', extent=[0, 1, 0, 1],
           aspect='auto', cmap='hot', interpolation='bilinear')
plt.colorbar(label='Object count')
plt.xlabel('Relative X center'); plt.ylabel('Relative Y center')
plt.title('BBox Center Position Heatmap')
plt.tight_layout()
plt.savefig(PLOT_DIR / 'bbox_heatmap.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/bbox_heatmap.png")
# Out:
# Saved → /kaggle/working/plots/bbox_heatmap.png

# %% [markdown]
# ### 2.6 Sample Images with Annotations

# %%
def show_annotated_images(image_ids, df, img_dir, ncols=3, figsize=(18, 12)):
    nrows = (len(image_ids) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    axes = axes.flatten()
    cmap = plt.cm.get_cmap('tab20', df['class_name'].nunique())
    classes_list = sorted(df['class_name'].unique())
    cls_color = {c: cmap(i) for i, c in enumerate(classes_list)}

    for ax, img_id in zip(axes, image_ids):
        img_path = img_dir / img_id
        if not img_path.exists():
            ax.axis('off'); continue
        ax.imshow(Image.open(img_path))
        rows = df[df['image_id'] == img_id]
        for _, row in rows.iterrows():
            x, y = row['x_min'], row['y_min']
            w, h = row['x_max'] - row['x_min'], row['y_max'] - row['y_min']
            color = cls_color[row['class_name']]
            ax.add_patch(patches.Rectangle((x, y), w, h, linewidth=1.5, edgecolor=color, facecolor='none'))
            ax.text(x, y-2, row['class_name'], fontsize=6, color='white', backgroundcolor=color, clip_on=True)
        ax.set_title(f"{img_id} ({len(rows)} objects)", fontsize=9)
        ax.axis('off')

    for ax in axes[len(image_ids):]:
        ax.axis('off')
    plt.tight_layout()
    plt.savefig(PLOT_DIR / 'sample_train_images.png', bbox_inches='tight')
    plt.close()
    print(f"Saved → {PLOT_DIR}/sample_train_images.png")


low_density  = objs_per_img[objs_per_img <= 3].index[:3].tolist()
high_density = objs_per_img[objs_per_img >= 20].index[:3].tolist()
show_annotated_images(low_density + high_density, df, TRAIN_IMG_DIR)
# Out:
# Saved → /kaggle/working/plots/sample_train_images.png

# %% [markdown]
# ### 2.7 EDA Summary → Hyperparameter Decisions
#
# | Finding | Impact | Decision |
# |---------|--------|----------|
# | Objects avg 34×34px on 800px image | Small objects need high resolution | `imgsz=800` |
# | 550× class imbalance | Rare classes under-detected | Focal loss (built-in YOLO), oversample via mosaic |
# | Max 202 objects/image | Dense scenes need good NMS | Keep `iou=0.5` for NMS |
# | All images 800×600, uniform bg | No strong spatial bias | Standard augmentation |
# | Objects roughly square (AR≈1) | No special anchor tuning needed | Default anchors OK |

# %% [markdown]
# ## 3. Prepare YOLO Dataset

# %%
# Build class mapping (sorted alphabetically → stable across runs)
classes   = sorted(df['class_name'].unique().tolist())  # Python list, not numpy
class2idx = {c: i for i, c in enumerate(classes)}
idx2class = {i: c for c, i in class2idx.items()}

print(f"Number of classes: {len(classes)}")
for i, c in idx2class.items():
    print(f"  {i:2d}: {c}")
# Out:
# Number of classes: 23
#    0: AsiaticRiceBorer
#    1: BlackCutworm
#    2: BrownPlantHopper
#    3: CornBorer
#    4: GrainSpreaderThrips
#    5: Grub
#    6: LargeCutworm
#    7: MoleCricket
#    8: PaddyStemMaggot
#    9: RedSpider
#   10: RiceGallMidge
#   11: RiceLeafCaterpillar
#   12: RiceLeafRoller
#   13: RiceLeafhopper
#   14: RiceShellPest
#   15: RiceStemfly
#   16: RiceWaterWeevil
#   17: SmallBrownPlantHopper
#   18: WhiteBackedPlantHopper
#   19: WhiteMarginedMoth
#   20: Wireworm
#   21: YellowCutworm
#   22: YellowRiceBorer

# %%
# Create YOLO directory structure
for split in ['train', 'val']:
    (DATASET_DIR / split / 'images').mkdir(parents=True, exist_ok=True)
    (DATASET_DIR / split / 'labels').mkdir(parents=True, exist_ok=True)

# Stratified-by-image train/val split (ensures rare classes appear in both)
all_image_ids = df['image_id'].unique().tolist()   # Python list
random.shuffle(all_image_ids)                      # seed set at top
n_val        = int(len(all_image_ids) * VAL_SPLIT)
val_ids      = set(all_image_ids[:n_val])
train_ids    = set(all_image_ids[n_val:])

print(f"Train images : {len(train_ids):,}")
print(f"Val   images : {len(val_ids):,}")
# Out:
# Train images : 11,431
# Val   images : 1,270

# %%
def bbox_to_yolo(x_min, y_min, x_max, y_max, img_w, img_h):
    """Absolute xyxy → YOLO normalized cx cy w h, clamped to [0,1]."""
    cx = (x_min + x_max) / 2.0 / img_w
    cy = (y_min + y_max) / 2.0 / img_h
    w  = (x_max - x_min) / img_w
    h  = (y_max - y_min) / img_h
    return max(0.0, min(1.0, cx)), max(0.0, min(1.0, cy)), max(1e-4, min(1.0, w)), max(1e-4, min(1.0, h))


def write_yolo_files(image_id, split):
    """Symlink image + write YOLO label file. Returns True on success."""
    src = TRAIN_IMG_DIR / image_id
    if not src.exists():
        return False

    # Symlink instead of copy — instant, zero disk usage
    dst_img = DATASET_DIR / split / 'images' / image_id
    if not dst_img.exists():
        os.symlink(str(src.resolve()), str(dst_img))

    rows  = df[df['image_id'] == image_id]
    img_w = int(rows.iloc[0]['width'])
    img_h = int(rows.iloc[0]['height'])
    lbl   = DATASET_DIR / split / 'labels' / (Path(image_id).stem + '.txt')

    with open(lbl, 'w') as f:
        for _, row in rows.iterrows():
            cls_id = class2idx[row['class_name']]
            cx, cy, w, h = bbox_to_yolo(
                row['x_min'], row['y_min'], row['x_max'], row['y_max'], img_w, img_h
            )
            f.write(f"{cls_id} {cx:.6f} {cy:.6f} {w:.6f} {h:.6f}\n")
    return True

# %%
missing = 0
for img_id in tqdm(train_ids, desc='Prepare train'):
    if not write_yolo_files(img_id, 'train'):
        missing += 1

for img_id in tqdm(val_ids, desc='Prepare val'):
    if not write_yolo_files(img_id, 'val'):
        missing += 1

n_train_imgs = len(list((DATASET_DIR / 'train' / 'images').glob('*.jpg')))
n_val_imgs   = len(list((DATASET_DIR / 'val'   / 'images').glob('*.jpg')))
n_train_lbls = len(list((DATASET_DIR / 'train' / 'labels').glob('*.txt')))
n_val_lbls   = len(list((DATASET_DIR / 'val'   / 'labels').glob('*.txt')))

print(f"Train  — images: {n_train_imgs:,}  labels: {n_train_lbls:,}")
print(f"Val    — images: {n_val_imgs:,}  labels: {n_val_lbls:,}")
print(f"Missing images : {missing}")
assert n_train_imgs == n_train_lbls, "Image/label count mismatch in train!"
assert n_val_imgs   == n_val_lbls,   "Image/label count mismatch in val!"
print("Dataset structure validated.")
# Out:
# Prepare train:   0%|          | 0/11431 [00:00<?, ?it/s]
# Prepare val:   0%|          | 0/1270 [00:00<?, ?it/s]
# Train  — images: 11,431  labels: 11,431
# Val    — images: 1,270  labels: 1,270
# Missing images : 0
# Dataset structure validated.

# %%
# Write dataset YAML
yaml_cfg = {
    'path'  : str(DATASET_DIR),
    'train' : 'train/images',
    'val'   : 'val/images',
    'nc'    : len(classes),
    'names' : classes          # Python list — YOLO needs this exactly
}

yaml_path = WORK_DIR / 'dataset.yaml'
with open(yaml_path, 'w') as f:
    yaml.dump(yaml_cfg, f, default_flow_style=None, sort_keys=False)

print(f"YAML written to: {yaml_path}")
print(open(yaml_path).read())
# Out:
# YAML written to: /kaggle/working/dataset.yaml
# path: /kaggle/working/dataset
# train: train/images
# val: val/images
# nc: 23
# names: [AsiaticRiceBorer, BlackCutworm, BrownPlantHopper, CornBorer, GrainSpreaderThrips,
#   Grub, LargeCutworm, MoleCricket, PaddyStemMaggot, RedSpider, RiceGallMidge, RiceLeafCaterpillar,
#   RiceLeafRoller, RiceLeafhopper, RiceShellPest, RiceStemfly, RiceWaterWeevil, SmallBrownPlantHopper,
#   WhiteBackedPlantHopper, WhiteMarginedMoth, Wireworm, YellowCutworm, YellowRiceBorer]

# %% [markdown]
# ## 4. Train YOLOv8m

# %%
from ultralytics import YOLO

model = YOLO(MODEL_NAME)   # COCO pretrained weights

train_results = model.train(
    data          = str(yaml_path),
    epochs        = EPOCHS,
    imgsz         = IMG_SIZE,
    batch         = BATCH_SIZE,
    device        = 0 if torch.cuda.is_available() else 'cpu',
    project       = str(WORK_DIR / 'runs'),
    name          = 'pest_v1',
    exist_ok      = True,
    # Stopping
    patience      = 10,
    # Optimizer
    optimizer     = 'AdamW',
    lr0           = 0.001,
    lrf           = 0.01,
    momentum      = 0.937,
    weight_decay  = 0.0005,
    warmup_epochs = 3,
    # Augmentation
    hsv_h         = 0.015,
    hsv_s         = 0.7,
    hsv_v         = 0.4,
    degrees       = 5.0,
    translate     = 0.1,
    scale         = 0.5,
    fliplr        = 0.5,
    flipud        = 0.0,
    mosaic        = 1.0,
    mixup         = 0.1,
    copy_paste    = 0.0,
    # Memory / IO — disk cache needs 23GB but Kaggle only has ~19GB free
    cache         = False,
    workers       = 4,
    # verbose=False prevents browser tab OOM from training log flooding
    verbose       = False,
    save          = True,
    save_period   = 5,
    val           = True,
    seed          = SEED,
)

print(f"Best mAP50 : {train_results.results_dict.get('metrics/mAP50(B)', 'N/A')}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 187.3MB/s 0.3s0.2s<0.1s
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=40, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=pest_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/pest_v1, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=23
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3789013  ultralytics.nn.modules.head.Detect           [23, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,869,637 parameters, 25,869,621 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 72.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 14.3±2.4 MB/s, size: 93.9 KB)
# train: Scanning /kaggle/working/dataset/train/labels... 11431 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 11431/11431 424.6it/s 26.9s<0.1s
# train: /kaggle/working/dataset/train/images/0001707.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 9.1±6.5 MB/s, size: 77.0 KB)
# val: Scanning /kaggle/working/dataset/val/labels... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 403.7it/s 3.1s0.0s
# val: New cache created: /kaggle/working/dataset/val/labels.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/pest_v1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/pest_v1
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      8.46G      1.689      1.893      1.096         88        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:18<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.4it/s 17.0s0.4s
#                    all       1270      10185      0.556      0.257      0.264      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40       7.1G      1.636      1.524      1.083         88        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:20<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.2s0.4s
#                    all       1270      10185      0.588       0.34      0.307      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40       7.1G      1.611      1.445      1.074         32        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.2s0.4s
#                    all       1270      10185      0.518      0.376      0.331      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40       7.1G      1.589       1.34      1.064         74        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185       0.57      0.374      0.356      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      7.69G      1.571      1.271       1.06        126        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.1s0.4s
#                    all       1270      10185      0.687      0.382      0.435      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      6.81G      1.546      1.221      1.051         29        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.627       0.44      0.438      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      7.27G      1.523       1.19      1.039        315        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.548      0.448      0.402      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      7.27G      1.441      1.143      1.022         60        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:14<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.585      0.443      0.444      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      7.27G      1.418      1.109      1.013         50        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.654      0.497      0.516      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      7.27G      1.397      1.083      1.009        172        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.1s0.4s
#                    all       1270      10185      0.575      0.512      0.511      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      7.27G      1.385       1.05      1.003         59        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.614      0.527      0.538      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      7.27G      1.378      1.032      1.001         58        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.613      0.481      0.511      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      7.27G      1.364      1.005     0.9966         94        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.615      0.486      0.516      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      7.27G       1.36      0.995     0.9949        137        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.652      0.518      0.541      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      7.27G      1.352     0.9726     0.9917         61        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.628       0.52      0.556      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      7.27G      1.349     0.9628     0.9897         76        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.578      0.525      0.543       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      7.27G      1.342     0.9594     0.9886         63        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185       0.63      0.544      0.561      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      7.27G      1.335      0.928     0.9893        155        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:15<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.694      0.552      0.573      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      7.27G      1.333     0.9276     0.9849        165        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.659      0.535       0.58       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      7.27G       1.33     0.9127     0.9839        109        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.8s0.4s
#                    all       1270      10185      0.654      0.537      0.574      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      7.27G      1.324     0.8985     0.9799        104        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.0s0.4s
#                    all       1270      10185      0.638      0.576      0.599      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      7.27G      1.319     0.8901     0.9827         74        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.2s0.4s
#                    all       1270      10185      0.683       0.56      0.609      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      7.27G      1.319     0.8888     0.9812        116        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.2s0.4s
#                    all       1270      10185      0.628      0.601      0.612      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      7.27G      1.308     0.8649     0.9741         74        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 16.3s0.4s
#                    all       1270      10185      0.645      0.603      0.623      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      7.27G      1.307     0.8555     0.9741        105        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185       0.68      0.595      0.618      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      7.27G      1.299     0.8491     0.9761        190        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.728       0.58      0.616       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      7.27G      1.297     0.8399     0.9729        192        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185       0.63      0.612      0.623      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      7.86G      1.294     0.8371     0.9692         74        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.8s0.4s
#                    all       1270      10185      0.653      0.611      0.629      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      7.21G      1.288     0.8259     0.9667         52        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.644      0.624      0.632      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      7.21G      1.284     0.8248     0.9684        128        640: 100% ━━━━━━━━━━━━ 715/715 1.6it/s 7:16<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.8s0.4s
#                    all       1270      10185       0.64      0.628      0.636      0.395
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      7.21G      1.248      0.738     0.9935         86        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.608      0.631      0.623      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      7.21G      1.235     0.7185     0.9861         98        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.614      0.633      0.629      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      7.21G      1.238     0.7126      0.985         41        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.8s0.4s
#                    all       1270      10185      0.669       0.61      0.645      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      7.21G       1.23      0.706     0.9853         24        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:12<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.652      0.631      0.647        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      7.21G      1.224      0.692     0.9812        110        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:10<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.7s0.4s
#                    all       1270      10185      0.628      0.646      0.648      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      7.21G      1.215     0.6821     0.9813         69        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:10<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.7s0.4s
#                    all       1270      10185      0.631      0.657      0.651      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      7.21G      1.209     0.6704     0.9805         60        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:11<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.8s0.4s
#                    all       1270      10185       0.62      0.654      0.645      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      7.21G        1.2     0.6648     0.9767         40        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.625      0.644      0.644      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      7.21G      1.205     0.6588     0.9755         23        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:10<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.624      0.647      0.642      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      7.21G      1.196     0.6553     0.9752         55        640: 100% ━━━━━━━━━━━━ 715/715 1.7it/s 7:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.5it/s 15.9s0.4s
#                    all       1270      10185      0.589      0.664       0.64        0.4
#
# 40 epochs completed in 5.022 hours.
# Optimizer stripped from /kaggle/working/runs/pest_v1/weights/last.pt, 52.0MB
# Optimizer stripped from /kaggle/working/runs/pest_v1/weights/best.pt, 52.0MB
#
# Validating /kaggle/working/runs/pest_v1/weights/best.pt...
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,853,077 parameters, 0 gradients, 78.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 40/40 2.4it/s 16.5s0.4s
#                    all       1270      10185      0.624      0.648      0.642      0.403
# Speed: 0.1ms preprocess, 8.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/pest_v1
# Best mAP50 : 0.6421594549418246

# %%
# Locate the best checkpoint
best_ckpt = WORK_DIR / 'runs' / 'pest_v1' / 'weights' / 'best.pt'
last_ckpt = WORK_DIR / 'runs' / 'pest_v1' / 'weights' / 'last.pt'

assert best_ckpt.exists(), f"best.pt not found — training may have failed: {best_ckpt}"
print(f"best.pt : {best_ckpt}")
print(f"last.pt : {last_ckpt}")
# Out:
# best.pt : /kaggle/working/runs/pest_v1/weights/best.pt
# last.pt : /kaggle/working/runs/pest_v1/weights/last.pt

# %% [markdown]
# ## 5. Validation Metrics

# %%
best_model = YOLO(str(best_ckpt))

val_metrics = best_model.val(
    data    = str(yaml_path),
    imgsz   = IMG_SIZE,
    conf    = CONF_THRESH,
    iou     = 0.5,
    device  = 0 if torch.cuda.is_available() else 'cpu',
    verbose = False,
)

print(f"\n{'='*40}")
print(f"  mAP@0.5      : {val_metrics.box.map50:.4f}")
print(f"  mAP@0.5:0.95 : {val_metrics.box.map:.4f}")
print(f"  Precision    : {val_metrics.box.mp:.4f}")
print(f"  Recall       : {val_metrics.box.mr:.4f}")
print(f"{'='*40}")
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,853,077 parameters, 0 gradients, 78.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 87.5±70.6 MB/s, size: 89.7 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 484.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.3s0.4ss
#                    all       1270      10185      0.625       0.65      0.569      0.362
# Speed: 0.7ms preprocess, 19.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#
# ========================================
#   mAP@0.5      : 0.5691
#   mAP@0.5:0.95 : 0.3622
#   Precision    : 0.6254
#   Recall       : 0.6496
# ========================================

# %%
# Per-class mAP
if hasattr(val_metrics.box, 'ap_class_index'):
    per_class_ap = val_metrics.box.ap50
    class_names_val = [classes[i] for i in val_metrics.box.ap_class_index]
    per_class_df = pd.DataFrame({'class': class_names_val, 'AP50': per_class_ap})
    per_class_df = per_class_df.sort_values('AP50')

    plt.figure(figsize=(10, 6))
    colors = plt.cm.RdYlGn(per_class_df['AP50'])
    plt.barh(per_class_df['class'], per_class_df['AP50'], color=colors)
    plt.axvline(per_class_df['AP50'].mean(), color='red', linestyle='--',
                label=f"Mean={per_class_df['AP50'].mean():.3f}")
    plt.xlabel('AP@0.5'); plt.title('Per-Class Average Precision @ IoU 0.5'); plt.legend()
    plt.tight_layout()
    plt.savefig(PLOT_DIR / 'per_class_ap.png', bbox_inches='tight')
    plt.close()
    print(f"Saved → {PLOT_DIR}/per_class_ap.png")
    print("\nWorst performing classes:")
    print(per_class_df.head(5).to_string(index=False))
# Out:
# Saved → /kaggle/working/plots/per_class_ap.png
#
# Worst performing classes:
#               class     AP50
#   WhiteMarginedMoth 0.000000
# GrainSpreaderThrips 0.032000
#            Wireworm 0.082500
#           CornBorer 0.293571
#      RiceLeafhopper 0.325780

# %% [markdown]
# ## 6. Confidence Threshold Tuning

# %%
conf_results = []
for conf in [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40]:
    r = best_model.val(
        data=str(yaml_path), imgsz=IMG_SIZE, conf=conf, iou=0.5,
        device=0 if torch.cuda.is_available() else 'cpu', verbose=False
    )
    conf_results.append({'conf': conf, 'mAP50': r.box.map50})
    print(f"  conf={conf:.2f}  mAP50={r.box.map50:.4f}")

conf_df = pd.DataFrame(conf_results)
best_conf_row = conf_df.loc[conf_df['mAP50'].idxmax()]
BEST_CONF = float(best_conf_row['conf'])
print(f"\nBest confidence threshold: {BEST_CONF}  (mAP50={best_conf_row['mAP50']:.4f})")

plt.figure(figsize=(8, 4))
plt.plot(conf_df['conf'], conf_df['mAP50'], marker='o')
plt.axvline(BEST_CONF, color='red', linestyle='--', label=f'Best={BEST_CONF}')
plt.xlabel('Confidence Threshold'); plt.ylabel('mAP@0.5')
plt.title('mAP vs Confidence Threshold'); plt.legend()
plt.tight_layout()
plt.savefig(PLOT_DIR / 'conf_sweep.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/conf_sweep.png")
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 143.8±38.7 MB/s, size: 95.0 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 532.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s0.4ss
#                    all       1270      10185      0.625      0.647      0.626      0.393
# Speed: 0.7ms preprocess, 19.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-2
#   conf=0.05  mAP50=0.6256
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 109.9±30.6 MB/s, size: 78.9 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 591.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s0.4ss
#                    all       1270      10185      0.625      0.648      0.612      0.385
# Speed: 0.7ms preprocess, 19.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-3
#   conf=0.10  mAP50=0.6124
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 173.7±53.0 MB/s, size: 93.3 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 484.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.1s0.4ss
#                    all       1270      10185      0.625      0.648      0.601      0.379
# Speed: 0.8ms preprocess, 19.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-4
#   conf=0.15  mAP50=0.6014
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 111.9±74.3 MB/s, size: 82.6 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 532.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.0s0.4ss
#                    all       1270      10185      0.624      0.639      0.584       0.37
# Speed: 0.7ms preprocess, 19.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-5
#   conf=0.20  mAP50=0.5840
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 97.4±46.0 MB/s, size: 97.8 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 409.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 30.0s0.4ss
#                    all       1270      10185      0.625       0.65      0.569      0.362
# Speed: 0.8ms preprocess, 19.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-6
#   conf=0.25  mAP50=0.5691
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 149.6±28.8 MB/s, size: 84.1 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 591.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.9s0.4ss
#                    all       1270      10185      0.634      0.624      0.555      0.353
# Speed: 0.7ms preprocess, 19.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-7
#   conf=0.30  mAP50=0.5547
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 96.8±88.5 MB/s, size: 88.2 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 591.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.6it/s 30.3s0.4ss
#                    all       1270      10185      0.627      0.599      0.538      0.343
# Speed: 0.7ms preprocess, 19.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-8
#   conf=0.35  mAP50=0.5383
# Ultralytics 8.4.39 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 86.1±22.7 MB/s, size: 88.5 KB)
# val: Scanning /kaggle/working/dataset/val/labels.cache... 1270 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1270/1270 484.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 80/80 2.7it/s 29.8s0.4ss
#                    all       1270      10185      0.644      0.577      0.522      0.333
# Speed: 0.8ms preprocess, 19.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-9
#   conf=0.40  mAP50=0.5219
#
# Best confidence threshold: 0.05  (mAP50=0.6256)
# Saved → /kaggle/working/plots/conf_sweep.png

# %% [markdown]
# ## 7. Generate Predictions on Test Set

# %%
test_image_paths = sorted(TEST_DIR.glob('*.jpg'))
print(f"Test images: {len(test_image_paths)}")
# Out:
# Test images: 7600

# %%
def format_prediction_string(result):
    """Convert a single YOLO result → competition PredictionString.

    Format: Label Confidence X_min Y_min X_max Y_max (space-separated per object)
    Coordinates are absolute integer pixel values.
    """
    if result.boxes is None or len(result.boxes) == 0:
        return ''

    parts = []
    # Vectorised extraction (faster than looping one box at a time)
    xyxy   = result.boxes.xyxy.cpu().numpy()   # (N, 4)
    confs  = result.boxes.conf.cpu().numpy()   # (N,)
    clsids = result.boxes.cls.cpu().numpy().astype(int)  # (N,)

    for cls_id, conf, (x1, y1, x2, y2) in zip(clsids, confs, xyxy):
        label = idx2class[cls_id]
        parts.append(f"{label} {conf:.4f} {int(x1)} {int(y1)} {int(x2)} {int(y2)}")

    return ' '.join(parts)

# %%
predictions = {}

for i in tqdm(range(0, len(test_image_paths), INFER_BATCH), desc='Inference'):
    batch_paths = test_image_paths[i : i + INFER_BATCH]
    results = best_model.predict(
        source  = [str(p) for p in batch_paths],
        imgsz   = IMG_SIZE,
        conf    = BEST_CONF,
        iou     = NMS_IOU,
        device  = 0 if torch.cuda.is_available() else 'cpu',
        augment = True,      # test-time augmentation boosts mAP
        verbose = False,
    )
    for path, res in zip(batch_paths, results):
        predictions[path.name] = format_prediction_string(res)

n_empty = sum(1 for v in predictions.values() if v == '')
print(f"Predicted {len(predictions)} images — {n_empty} with no detections")
# Out:
# Inference:   0%|          | 0/238 [00:00<?, ?it/s]
# Predicted 7600 images — 3 with no detections

# %% [markdown]
# ## 8. Build & Save Submission CSV

# %%
sample_sub = pd.read_csv(SAMPLE_SUB)
print(f"Sample submission shape: {sample_sub.shape}")
sample_sub.head(3)
# Out:
# Sample submission shape: (7600, 2)
#        ImageID                  PredictionString
# 0  0000003.jpg  RiceLeafRoller 0.5 10 10 100 100
# 1  0000010.jpg  RiceLeafRoller 0.5 10 10 100 100
# 2  0000012.jpg  RiceLeafRoller 0.5 10 10 100 100

# %%
pred_df = pd.DataFrame([
    {'ImageID': img_id, 'PredictionString': pred_str}
    for img_id, pred_str in predictions.items()
])

# Left-join on sample_submission to guarantee row order and coverage
submission = sample_sub[['ImageID']].merge(pred_df, on='ImageID', how='left')
submission['PredictionString'] = submission['PredictionString'].fillna('')

# Sanity checks
assert len(submission) == len(sample_sub), \
    f"Row count mismatch: {len(submission)} vs {len(sample_sub)}"
assert list(submission.columns) == ['ImageID', 'PredictionString'], \
    f"Wrong columns: {list(submission.columns)}"

print(f"Submission rows          : {len(submission):,}")
print(f"Images with detections   : {(submission['PredictionString'] != '').sum():,}")
print(f"Images with no detections: {(submission['PredictionString'] == '').sum():,}")
print()
submission.head(5)
# Out:
# Submission rows          : 7,600
# Images with detections   : 7,597
# Images with no detections: 3
#        ImageID                                   PredictionString
# 0  0000003.jpg  YellowRiceBorer 0.8168 277 186 315 210 Asiatic...
# 1  0000010.jpg  YellowRiceBorer 0.8687 179 61 212 81 YellowRic...
# 2  0000012.jpg  RiceLeafRoller 0.8680 222 141 270 208 RiceStem...
# 3  0000019.jpg  YellowRiceBorer 0.8388 251 391 278 424 YellowR...
# 4  0000021.jpg  YellowRiceBorer 0.8424 228 256 263 279 YellowR...

# %%
# Validate PredictionString format on a sample
sample_preds = submission[submission['PredictionString'] != ''].head(3)
for _, row in sample_preds.iterrows():
    tokens = row['PredictionString'].split()
    n_objs = len(tokens) // 6
    print(f"{row['ImageID']}  ({n_objs} objects detected)")
    for j in range(n_objs):
        t = tokens[j*6 : j*6+6]
        print(f"    label={t[0]}  conf={t[1]}  bbox=[{t[2]},{t[3]},{t[4]},{t[5]}]")
# Out:
# 0000003.jpg  (23 objects detected)
#     label=YellowRiceBorer  conf=0.8168  bbox=[277,186,315,210]
#     label=AsiaticRiceBorer  conf=0.7684  bbox=[395,430,449,499]
#     label=RiceLeafCaterpillar  conf=0.7654  bbox=[192,456,227,504]
#     label=RiceStemfly  conf=0.6360  bbox=[103,369,137,404]
#     label=WhiteBackedPlantHopper  conf=0.4410  bbox=[217,354,272,402]
#     label=RiceLeafCaterpillar  conf=0.3477  bbox=[331,477,367,513]
#     label=BrownPlantHopper  conf=0.2698  bbox=[521,387,570,428]
#     label=RiceStemfly  conf=0.1852  bbox=[180,429,218,464]
#     label=AsiaticRiceBorer  conf=0.1276  bbox=[284,410,337,470]
#     label=BrownPlantHopper  conf=0.1234  bbox=[359,515,407,553]
#     label=RiceStemfly  conf=0.1146  bbox=[291,471,325,512]
#     label=RiceLeafCaterpillar  conf=0.1114  bbox=[162,99,192,137]
#     label=RiceLeafCaterpillar  conf=0.0995  bbox=[154,40,184,71]
#     label=RiceStemfly  conf=0.0946  bbox=[344,428,371,456]
#     label=RiceStemfly  conf=0.0827  bbox=[121,76,147,108]
#     label=BrownPlantHopper  conf=0.0779  bbox=[518,431,557,470]
#     label=RiceLeafCaterpillar  conf=0.0716  bbox=[304,401,336,434]
#     label=RiceLeafCaterpillar  conf=0.0709  bbox=[240,527,282,563]
#     label=RiceLeafCaterpillar  conf=0.0662  bbox=[520,386,568,428]
#     label=BrownPlantHopper  conf=0.0599  bbox=[277,496,326,537]
#     label=RiceLeafCaterpillar  conf=0.0564  bbox=[144,81,178,109]
#     label=RiceLeafCaterpillar  conf=0.0510  bbox=[115,208,159,242]
#     label=RiceStemfly  conf=0.0508  bbox=[82,276,105,307]
# 0000010.jpg  (34 objects detected)
#     label=YellowRiceBorer  conf=0.8687  bbox=[179,61,212,81]
#     label=YellowRiceBorer  conf=0.8402  bbox=[100,217,124,248]
#     label=YellowRiceBorer  conf=0.8392  bbox=[240,188,275,212]
#     label=YellowRiceBorer  conf=0.8346  bbox=[357,342,383,382]
#     label=PaddyStemMaggot  conf=0.8345  bbox=[425,365,506,435]
#     label=YellowRiceBorer  conf=0.8142  bbox=[476,142,512,168]
#     label=YellowRiceBorer  conf=0.7993  bbox=[93,256,124,281]
#     label=YellowRiceBorer  conf=0.7931  bbox=[155,165,188,187]
#     label=YellowRiceBorer  conf=0.7845  bbox=[345,121,385,144]
#     label=YellowRiceBorer  conf=0.7359  bbox=[191,180,220,220]
#     label=YellowRiceBorer  conf=0.6786  bbox=[167,31,198,62]
#     label=YellowRiceBorer  conf=0.5637  bbox=[172,116,193,155]
#     label=YellowRiceBorer  conf=0.5516  bbox=[302,136,339,156]
#     label=YellowRiceBorer  conf=0.5400  bbox=[141,139,168,161]
#     label=YellowRiceBorer  conf=0.5388  bbox=[397,558,419,589]
#     label=YellowRiceBorer  conf=0.4482  bbox=[210,262,233,289]
#     label=YellowRiceBorer  conf=0.3201  bbox=[208,136,239,160]
#     label=YellowRiceBorer  conf=0.3019  bbox=[278,248,300,274]
#     label=YellowRiceBorer  conf=0.2528  bbox=[174,4,196,33]
#     label=YellowRiceBorer  conf=0.2344  bbox=[203,220,229,248]
#     label=RiceLeafRoller  conf=0.1936  bbox=[755,409,795,447]
#     label=RiceLeafCaterpillar  conf=0.1836  bbox=[561,499,593,537]
#     label=BrownPlantHopper  conf=0.1782  bbox=[334,518,367,557]
#     label=RiceStemfly  conf=0.1709  bbox=[135,209,162,234]
#     label=YellowRiceBorer  conf=0.1696  bbox=[152,116,176,138]
#     label=YellowRiceBorer  conf=0.1618  bbox=[335,553,362,575]
#     label=YellowRiceBorer  conf=0.1377  bbox=[92,275,118,291]
#     label=YellowRiceBorer  conf=0.1302  bbox=[206,108,224,134]
#     label=YellowRiceBorer  conf=0.1132  bbox=[286,0,308,31]
#     label=YellowRiceBorer  conf=0.1109  bbox=[356,576,380,596]
#     label=YellowRiceBorer  conf=0.1029  bbox=[373,580,401,598]
#     label=YellowRiceBorer  conf=0.0986  bbox=[127,185,153,221]
#     label=YellowRiceBorer  conf=0.0757  bbox=[259,328,291,345]
#     label=YellowRiceBorer  conf=0.0670  bbox=[328,97,353,127]
# 0000012.jpg  (17 objects detected)
#     label=RiceLeafRoller  conf=0.8680  bbox=[222,141,270,208]
#     label=RiceStemfly  conf=0.8245  bbox=[74,157,102,189]
#     label=RiceLeafCaterpillar  conf=0.6841  bbox=[189,82,221,132]
#     label=WhiteBackedPlantHopper  conf=0.6439  bbox=[144,416,202,476]
#     label=RiceStemfly  conf=0.5591  bbox=[368,514,403,549]
#     label=RiceLeafhopper  conf=0.4110  bbox=[306,196,341,228]
#     label=WhiteBackedPlantHopper  conf=0.2713  bbox=[336,527,387,579]
#     label=BrownPlantHopper  conf=0.1378  bbox=[335,528,389,581]
#     label=BrownPlantHopper  conf=0.1151  bbox=[144,416,202,475]
#     label=WhiteBackedPlantHopper  conf=0.0923  bbox=[490,485,550,541]
#     label=RiceLeafCaterpillar  conf=0.0790  bbox=[91,204,129,245]
#     label=RiceStemfly  conf=0.0743  bbox=[42,147,66,178]
#     label=RiceStemfly  conf=0.0716  bbox=[309,531,343,560]
#     label=BrownPlantHopper  conf=0.0704  bbox=[490,485,550,540]
#     label=WhiteBackedPlantHopper  conf=0.0628  bbox=[414,428,461,478]
#     label=RiceStemfly  conf=0.0529  bbox=[250,121,271,152]
#     label=RiceLeafRoller  conf=0.0505  bbox=[409,581,463,600]

# %%
# Save CSV
sub_path = WORK_DIR / 'submission.csv'
submission.to_csv(sub_path, index=False)
print(f"Submission CSV saved → {sub_path}")
print(f"File size: {sub_path.stat().st_size / 1024:.1f} KB")

# Final read-back check
check = pd.read_csv(sub_path)
assert list(check.columns) == ['ImageID', 'PredictionString']
assert len(check) == len(sample_sub)
print("Read-back validation passed.")
# Out:
# Submission CSV saved → /kaggle/working/submission.csv
# File size: 4348.7 KB
# Read-back validation passed.

# %% [markdown]
# ## 9. Visualise Predictions on Test Samples

# %%
def show_test_predictions(image_ids, submission_df, test_dir, ncols=3, figsize=(18, 12)):
    nrows = (len(image_ids) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    axes = axes.flatten()
    cmap = plt.cm.get_cmap('tab20', len(classes))
    cls_color = {c: cmap(i) for i, c in enumerate(classes)}

    for ax, img_id in zip(axes, image_ids):
        img_path = test_dir / img_id
        if not img_path.exists():
            ax.axis('off'); continue
        ax.imshow(Image.open(img_path))
        pred_str = submission_df.loc[submission_df['ImageID'] == img_id, 'PredictionString'].values
        if len(pred_str) > 0 and pred_str[0] != '':
            tokens = pred_str[0].split()
            n_objs = len(tokens) // 6
            for j in range(n_objs):
                t = tokens[j*6:j*6+6]
                x1, y1, x2, y2 = int(t[2]), int(t[3]), int(t[4]), int(t[5])
                color = cls_color.get(t[0], (1, 0, 0, 1))
                ax.add_patch(patches.Rectangle((x1, y1), x2-x1, y2-y1,
                             linewidth=1.5, edgecolor=color, facecolor='none'))
                ax.text(x1, y1-2, f"{t[0]} {float(t[1]):.2f}", fontsize=6,
                        color='white', backgroundcolor=color, clip_on=True)
            ax.set_title(f"{img_id} ({n_objs} dets)", fontsize=9)
        else:
            ax.set_title(f"{img_id} (no dets)", fontsize=9, color='red')
        ax.axis('off')

    for ax in axes[len(image_ids):]:
        ax.axis('off')
    plt.suptitle('Test Set Predictions', fontsize=13)
    plt.tight_layout()
    plt.savefig(PLOT_DIR / 'test_predictions.png', bbox_inches='tight')
    plt.close()
    print(f"Saved → {PLOT_DIR}/test_predictions.png")


sample_test_ids = [p.name for p in random.sample(test_image_paths, min(6, len(test_image_paths)))]
show_test_predictions(sample_test_ids, submission, TEST_DIR)
# Out:
# Saved → /kaggle/working/plots/test_predictions.png

# %% [markdown]
# ## 10. Prediction Statistics

# %%
# Count predicted objects per test image and per class
pred_class_counts = Counter()
objs_per_test_img = []

for _, row in submission.iterrows():
    s = row['PredictionString']
    if s == '':
        objs_per_test_img.append(0)
        continue
    tokens = s.split()
    n = len(tokens) // 6
    objs_per_test_img.append(n)
    for j in range(n):
        pred_class_counts[tokens[j*6]] += 1

print(f"Total objects predicted : {sum(objs_per_test_img):,}")
print(f"Avg objects/test image  : {np.mean(objs_per_test_img):.1f}")

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
axes[0].hist(objs_per_test_img, bins=40, color='steelblue', edgecolor='white')
axes[0].set_title('Predicted Objects Per Test Image')
axes[0].set_xlabel('# Detections')

pred_cls_df = pd.DataFrame(pred_class_counts.most_common(), columns=['class', 'count'])
axes[1].barh(pred_cls_df['class'][::-1], pred_cls_df['count'][::-1], color='darkorange')
axes[1].set_title('Predicted Class Distribution (Test Set)')
axes[1].set_xlabel('# Predictions')

plt.tight_layout()
plt.savefig(PLOT_DIR / 'prediction_stats.png', bbox_inches='tight')
plt.close()
print(f"Saved → {PLOT_DIR}/prediction_stats.png")
# Out:
# Total objects predicted : 114,183
# Avg objects/test image  : 15.0
# Saved → /kaggle/working/plots/prediction_stats.png

# %% [markdown]
# ## Summary
#
# | Step | Detail |
# |------|--------|
# | Model | YOLOv8m — pretrained COCO, fine-tuned on 23-class pest data |
# | Image size | 640px |
# | Training | AdamW, mosaic+mixup aug, `cache=False`, early stop patience=10, 40 epochs (~3.5 GPU hrs) |
# | Inference | TTA (`augment=True`), threshold tuned on val set |
# | Output | `/kaggle/working/submission.csv` |
#
# **Kaggle submission**: download `submission.csv` → rename to `ROLL_NO.csv` → submit
# **Google Form**: download this notebook → rename to `ROLL_NO.ipynb` → submit
